# %%
print("hello world")
# Out:
# hello world

# %%
# concatenate String
print("hello " + "Donny")
print("hello " + " " + " Rivera")
# Out:
# hello Donny
# hello   Rivera

# %%
# On print in many lines
print("Hello\nDonny\nRivera")
# Out:
# Hello
# Donny
# Rivera

# %%
# concatenate String
print("Hello " + "Donny" + " Rivera")
print("Hello " + " " + "Rivera")
# Out:
# Hello Donny Rivera
# Hello  Rivera

# %%
# input function in python
print("Hello " + input("What is your name? ") + "!")
# Out:
# Hello donny!

# %%
# python Variables
name = "Donny Rivera"
print(name)
print("Hello " + name + "!")
# Out:
# Donny Rivera
# Hello Donny Rivera!

# %%
username = input("What is your name? ")
lenght = len(username)
print(lenght)

print(username[0])
# Out:
# 5
# D

# %% [markdown]
# ## Final Project Day 1

# %%
print("PROJECT 01 | BAND NAME GENERATOR")
city = input("What's is the name of the city you grew up in?\n")
pet = input("What's your pet's name?\n")
print('Your band name could be ' + city + ' ' + pet)
# Out:
# PROJECT 01 | BAND NAME GENERATOR
# Your band name could be Santiago Nina
