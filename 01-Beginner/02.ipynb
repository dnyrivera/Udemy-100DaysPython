# %% [markdown]
# ### Data Types

# %%
# Strings 
print("Hello"[1]) # Indexing strings
print("Hello"[-1]) # Indexing strings reverse
print("123" + "345") # Concatenation

# Integers
print("integers: " + str(123 + 345))

# Floats
print("floats: " + str(3.14159))

# Booleans
print("booleans: " + str(True))
print("booleans: " + str(False))

# Large numbers
print("large numbers: " + str(123_456_789))

# %%
len(str(12345))

print(type("hello"))
print(type(1234))
print(type(4.232332))
print(type(True))

# %%
len_user = str(len(input("Enter your name: ")))
print("Number of letters in your name: " + len_user)

# %%
# BMI Calculation 
weight = 105
heigth = 1.75 

bmi = weight / heigth ** 2 

print(bmi)
print(int(bmi))
print(round(bmi))
print(round(bmi,2))

# %%
# F-strings
score = 0 
heigth = 1.8
is_winning = True

print(f"Your score is = {score}, your heigth is {heigth}. You are winning is {is_winning}")

# %% [markdown]
# ## Final Project Day 2

# %%
print("PROJECT 02 | SPLIT BILL WITH TIP CALCULATOR")
total_bill = int(input("Enter the total Bill: "))
percent_tip = input("Enter the total Tip (10, 12 or 15): ")
qty_people = int(input("Enter how many people to Split: "))

result = total_bill * float("1."+percent_tip) / qty_people
print(f"Each person should pay: ${result}")
# Out:
# PROJECT 02 | SPLIT BILL WITH TIP CALCULATOR
# Each person should pay: $33.0
